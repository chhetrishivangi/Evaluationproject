# %% [markdown]
# # BaseBall Case Study

# %% [markdown]
# Project Description
#
# This dataset utilizes data from 2014 Major League Baseball seasons in order to develop an algorithm that predicts the number of wins for a given team in the 2015 season based on several different indicators of success. There are 16 different features that will be used as the inputs to the machine learning and the output will be a value that represents the number of wins.
#
# Input Features: Runs, At Bats, Hits, Doubles, Triples, Home runs, Walks, Strikeouts, Stolen Bases, Runs Allowed, Earned Runs, Earned Run Average (ERA), Shutouts, Saves and Errors
#
# Output: Number of predicted wins

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
import os
import scipy as stats
# %matplotlib inline
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("baseball.csv")
df
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 5    93  891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# ...

# %% [markdown]
# The above dataset contains 17 columns which contains the statistics summary of the baseball players.
#
# Out of 17 columns 1 W column is our target variable which contains the number of predicted wins.
#
# Further the above dataset only contains the numerical values and there is no categorical data present. So the above dataset is a Regression  problem

# %%
df.head()
# Out:
#     W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  \
# 0  95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8
# 1  83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12
# 2  81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11   10
# 3  76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7    9
# 4  74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7   12
#
#    SV    E
# 0  56   88
# 1  45   86
# 2  38   79
# 3  37  101
# 4  35   86

# %% [markdown]
# In the above dataset df.head shows the data of first 5 columns of the data

# %%
df.tail()
# Out:
#      W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 25  92  667  5385  1346  263  26  187  563  1258   59  595  553  3.44   6
# 26  84  696  5565  1486  288  39  136  457  1159   93  627  597  3.72   7
# 27  79  720  5649  1494  289  48  154  490  1312  132  713  659  4.04   1
# 28  74  650  5457  1324  260  36  148  426  1327   82  731  655  4.09   1
# 29  68  737  5572  1479  274  49  186  388  1283   97  844  799  5.04   4
#
#     SHO  SV   E
# 25   21  47  75
# 26   18  41  78
# 27   12  44  86
# 28    6  41  92
# 29    4  36  95

# %% [markdown]
# df.tail shows the bottom 5 columns of the dataset

# %%
df.columns
# Out:
# Index(['W', 'R', 'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'RA', 'ER',
#        'ERA', 'CG', 'SHO', 'SV', 'E'],
#       dtype='object')

# %% [markdown]
# df.columns shows the name of the columns in which data is categorized

# %%
df.rename(columns={'W' : 'Wins', 
                   'R' : 'Runs Scored', 
                  'AB' : 'At Bat', 
                   'H' : 'Hits', 
                  '2B' : 'Doubles', 
                  '3B' : 'Triples',
                  'HR' : 'Home Runs', 
                  'BB' : 'Base on Balls', 
                  'SO' : 'Strike Outs', 
                  'SB' : 'Stolen Base',
                  'RA' : 'Runs Average', 
                  'ER' : 'Earned Runs', 
                 'ERA' : 'Earned Run Average', 
                  'CG' : 'Complete Game',
                 'SHO' : 'Shut Outs', 
                  'SV' : 'Saves', 
                   'E' : 'Errors'}, 
          inplace=True)

# %% [markdown]
# In the above columns we have rename the columns of the dataset

# %%
df
# Out:
#     Wins  Runs Scored  At Bat  Hits  Doubles  Triples  Home Runs  \
# 0     95          724    5575  1497      300       42        139
# 1     83          696    5467  1349      277       44        156
# 2     81          669    5439  1395      303       29        141
# 3     76          622    5533  1381      260       27        136
# 4     74          689    5605  1515      289       49        151
# 5     93          891    5509  1480      308       17        232
# 6     87          764    5567  1397      272       19        212
# 7     81          713    5485  1370      246       20        217
# 8     80          644    5485  1383      278       32        167
# 9     78          748    5640  1495      294       33        161
# 10    88          751    5511  1419      279       32        172
# 11    86          729    5459  1363      278       26        230
# 12    85          661    5417  1331      243       21        176
# ...

# %% [markdown]
# After renaming the columns we have called the whole dataset again

# %% [markdown]
# # Exploratory Data Analysis (EDA)

# %%
# Checking the dimension of the dataset
df.shape
# Out:
# (30, 17)

# %% [markdown]
# The above dataset consists of 30 rows and 17 columns.
#
# Out of which 1 is target variable and remaining 16 are independent variables

# %%
# Checking the types of the dataset
df.dtypes
# Out:
# Wins                    int64
# Runs Scored             int64
# At Bat                  int64
# Hits                    int64
# Doubles                 int64
# Triples                 int64
# Home Runs               int64
# Base on Balls           int64
# Strike Outs             int64
# Stolen Base             int64
# Runs Average            int64
# Earned Runs             int64
# Earned Run Average    float64
# Complete Game           int64
# Shut Outs               int64
# Saves                   int64
# Errors                  int64
# dtype: object

# %% [markdown]
# In the above dataset all the columns have integer datatype except earned run average which have float datatype.
#
# The datatype of the dataset is object

# %%
# To get good overview of the dataset

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 17 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Wins                30 non-null     int64
#  1   Runs Scored         30 non-null     int64
#  2   At Bat              30 non-null     int64
#  3   Hits                30 non-null     int64
#  4   Doubles             30 non-null     int64
#  5   Triples             30 non-null     int64
#  6   Home Runs           30 non-null     int64
#  7   Base on Balls       30 non-null     int64
#  8   Strike Outs         30 non-null     int64
#  9   Stolen Base         30 non-null     int64
#  10  Runs Average        30 non-null     int64
#  11  Earned Runs         30 non-null     int64
#  12  Earned Run Average  30 non-null     float64
#  13  Complete Game       30 non-null     int64
#  14  Shut Outs           30 non-null     int64
#  15  Saves               30 non-null     int64
# ...

# %% [markdown]
# The above info method shows that we have 17 columns Wins, Runs Scored, At Bat, Hits, Doubles, Triples, Home Runs, Base on Balls, Strike Outs, Stolen Base, Runs Average, Earned Runs, Earned Run Average, Complete Game, Shut Outs,Saves and  Errors.
#
# Out of which 1 column consists of output variable and 30 rows.
#
# In the above dataset there is no null values present
#
# In the dataset there is 16 columns which have integer datatype and column Earned Run Average have float type which consist of decimal values
#
# The total memory usage of the dataset is 4.1 KB

# %%
# Checking the number of unique values in each column
df.nunique()
# Out:
# Wins                  24
# Runs Scored           28
# At Bat                29
# Hits                  29
# Doubles               22
# Triples               23
# Home Runs             27
# Base on Balls         29
# Strike Outs           29
# Stolen Base           27
# Runs Average          30
# Earned Runs           30
# Earned Run Average    30
# Complete Game          9
# Shut Outs             12
# Saves                 20
# Errors                21
# dtype: int64

# %% [markdown]
# In the above dataset there are number of different unique values present in the different columns of the dataset

# %%
# Checking the sum of null values
df.isnull().sum()
# Out:
# Wins                  0
# Runs Scored           0
# At Bat                0
# Hits                  0
# Doubles               0
# Triples               0
# Home Runs             0
# Base on Balls         0
# Strike Outs           0
# Stolen Base           0
# Runs Average          0
# Earned Runs           0
# Earned Run Average    0
# Complete Game         0
# Shut Outs             0
# Saves                 0
# Errors                0
# dtype: int64

# %% [markdown]
# This method shows there is no null value is present in the above dataset
#
# The datatype of the dataset is integer

# %%
# Let visualize it using heatmap
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# In heatmap there is no null value present in the data.As we can clearly visualize that

# %%
# Checking the uniqueness of output variable
df['Wins'].unique()
# Out:
# array([ 95,  83,  81,  76,  74,  93,  87,  80,  78,  88,  86,  85,  68,
#        100,  98,  97,  64,  90,  71,  67,  63,  92,  84,  79], dtype=int64)

# %% [markdown]
# There are the number of unique values present in the target variable 'Wins' and the datatype of the output column is integer

# %%
# Checking the value counts in target variable
df["Wins"].value_counts()
# Out:
# 68     3
# 81     2
# 76     2
# 74     2
# 83     2
# 98     1
# 84     1
# 92     1
# 63     1
# 67     1
# 71     1
# 90     1
# 64     1
# 97     1
# 95     1
# 100    1
# 85     1
# 86     1
# 88     1
# 78     1
# 80     1
# 87     1
# 93     1
# 79     1
# Name: Wins, dtype: int64

# %% [markdown]
# This method shows the value counts present in the output data

# %%
# Checking the space in total charges columns
df.loc[df['Wins']==" "]
# Out:
# Empty DataFrame
# Columns: [Wins, Runs Scored, At Bat, Hits, Doubles, Triples, Home Runs, Base on Balls, Strike Outs, Stolen Base, Runs Average, Earned Runs, Earned Run Average, Complete Game, Shut Outs, Saves, Errors]
# Index: []

# %% [markdown]
# In the above method there are no space in the dataset.

# %%
# Statistical summary of dataset
df.describe()
# Out:
#              Wins  Runs Scored       At Bat         Hits     Doubles  \
# count   30.000000    30.000000    30.000000    30.000000   30.000000
# mean    80.966667   688.233333  5516.266667  1403.533333  274.733333
# std     10.453455    58.761754    70.467372    57.140923   18.095405
# min     63.000000   573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000   651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000   689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000   718.250000  5570.000000  1451.500000  288.750000
# max    100.000000   891.000000  5649.000000  1515.000000  308.000000
#
#          Triples   Home Runs  Base on Balls  Strike Outs  Stolen Base  \
# count  30.000000   30.000000      30.000000     30.00000    30.000000
# mean   31.300000  163.633333     469.100000   1248.20000    83.500000
# std    10.452355   31.823309      57.053725    103.75947    22.815225
# ...

# %% [markdown]
# The above method describes the statistical information of the dataset.
#
# In the dataset there are no negative and no null values present in the data.
#
# In the target column the mean is bit less than median(50%), so it is skewed to the left.
#
# Since the mean is 80.96 and maximum is 100, it means that the team won more matches.
#
# In the column R(Runs) also median is more than the mean then it is skewed to left.
#
# These differences can also be seen in the columns 2B(Doubles), BB(Base on Balls), SO(Strike Outs), RA(Runs Average), ER(Earned Runs) ERA(Earned Run Average) and SHO(Shut Outs)
#
# The mean is more than median in the columns AB(At Bat), H(Hits), HR(Home Runs), SV(Saves)and E(Errors) which means they are skewed to right.
#
# There is a huge difference in max and 75% percentile.
#
# So from these observations we can conclude that the outliers are present in many of these columns.

# %%
#Checking the skewness
df.skew()
# Out:
# Wins                  0.047089
# Runs Scored           1.200786
# At Bat                0.183437
# Hits                  0.670254
# Doubles              -0.230650
# Triples               0.129502
# Home Runs             0.516441
# Base on Balls         0.158498
# Strike Outs          -0.156065
# Stolen Base           0.479893
# Runs Average          0.045734
# Earned Runs           0.058710
# Earned Run Average    0.053331
# Complete Game         0.736845
# Shut Outs             0.565790
# Saves                 0.657524
# Errors                0.890132
# dtype: float64

# %% [markdown]
# The acceptable range for skewness is between +/-0.5. We see columns such as Runs Scored, Hits, Runs Average, Earned Runs, Earned Run Average, Complete Game, Saves and Errors being slightly out of this range.

# %%
# Visualizing the statistics of the columns using Heatmap
plt.figure(figsize=(16,9))
sns.heatmap(df.describe(),linewidths=0.1,fmt='0.1f',annot=True)
# Out:
# <AxesSubplot:>

# %%
# Histogram for target variable
sns.histplot(df["Wins"])
# Out:
# <AxesSubplot:xlabel='Wins', ylabel='Count'>

# %% [markdown]
# The above plot shows that the data is normally distributed and there is no presence of skewness. The minimum wins of the team rate is 63 and maximum is 100 also mean of wins of the team rate is 80

# %%
# Checking data distriubted in each column
plt.figure(figsize=(20,25), facecolor='white')
plotnumber = 1

for column in df:
    if plotnumber<=18:
        ax = plt.subplot(6,4,plotnumber)
        sns.distplot(df[column],color='b')
        plt.xlabel(column,fontsize=20)
    plotnumber+=1
plt.show()

# %% [markdown]
# From the above distplots we observe that most of the columns are normally distributed and some of them have skewness too.
#
# The target column 'W'(wins) looks normally distributed and also we can observe there is no skewness. So from the graph it is clear that the winning rate is between 63 to 100 and mean of W is 80.
#
# The data in the feature 'R'(Runs) is not normal and the median is more than the mean so it is skewed to left.
#
# These differences can also be seen in the columns 'BB'(Walks), 'SO'(strike outs), 'RA'(Runs allowed), 'ERA'(Earned run average), 'SHO'(Shutouts). Eventhough they looks normal but has skewness.
#
# The data in the feature 'AB'(At Bats) looks normally distributed and has no skewness.
#
# The data in the features 'H'(Hits), 'HR'(homeruns),'SV'(saves) and 'E'(errors) are not normal and the mean is more than the median which means skewed to right.
#
# '2B'(doubles) also looks normal and bit skewness present since the median is bit more than mean.
#
# The mean and the median is almost same in the feature columns '3B'(tribles) and 'SB'(Stolen Bases) the data is normally distributed and there is no skewness.
#
# Also the column 'CG'(complete games) is looks almost normal and has no skewness
#
# The column 'ER'(Earned Runs) is normal and has no skewness.

# %%
plt.figure(figsize=(20,25), facecolor='white')
plotnumber = 1

for column in df:
    if plotnumber<=18:
        ax = plt.subplot(6,4,plotnumber)
        sns.boxplot(df[column],color='r')
        plt.xlabel(column,fontsize=20)
    plotnumber+=1
plt.show()

# %% [markdown]
# In the above method we find that there are outliers present in the run scored,earned run average,shut outs,saves and errors.
#
# We will remove these outliers using either Zscore or IQR method.

# %%
# Bivariate Analysis

plt.figure(figsize=[10,6])
plt.title('Comparision between Runs and Errors')
sns.scatterplot(df['Runs Scored'],df['Errors'],hue=df["Wins"]);
plt.xlabel("Runs")
plt.ylabel("Errors")
# Out:
# Text(0, 0.5, 'Errors')

# %% [markdown]
# The scatter plot gives the relation between the Runs and the Errors on the basis of Wins.
#
# There is no linear relationship between these columns.
#
# We can infer that there is no correlation.
#
# The runs between 650-730 with the error upto 95 has more wins. Also we can see the presence of outliers.

# %%
plt.figure(figsize=[10,6])
plt.title('Comparision between Runs and Hits')
sns.scatterplot(df['Runs Scored'],df['Hits'],hue=df["Wins"],palette="husl");
plt.xlabel("Runs")
plt.ylabel("Hits")
# Out:
# Text(0, 0.5, 'Hits')

# %% [markdown]
# In the above plot there is no linearity between the columns. Also the rate of runs is high in the range 650 to 750 with the rate of hits renges 1500, which means the wins of the team is more in these ranges.

# %%
plt.figure(figsize=[10,6])
plt.title('Comparision between AB and Hits')
sns.scatterplot(df['At Bat'],df['Hits'],hue=df['Wins']);
plt.xlabel("At Bats")
plt.ylabel("Hits")
# Out:
# Text(0, 0.5, 'Hits')

# %%
plt.figure(figsize=[10,6])
plt.title('Comparision between  and Hits')
sns.scatterplot(df['Runs Average'],df['Earned Run Average'],hue=df['Wins'],palette="husl");
plt.xlabel("Runs Allowed")
plt.ylabel("Earned Run Average")
# Out:
# Text(0, 0.5, 'Earned Run Average')

# %%
plt.figure(figsize=[10,6])
plt.title('Comparision between Runs and Wins ')
sns.lineplot(df['Runs Scored'],df['Wins'], color='y') 
plt.xlabel("Runs")
plt.ylabel("Wins")
# Out:
# Text(0, 0.5, 'Wins')

# %% [markdown]
# We can observe that the Runs rate is high in the range 640-650 followed by the range 700, so in this range the wins of team is also high. As the run rate increases the rate of wins also increases.

# %%
plt.figure(figsize=[10,6])
plt.title('Comparision between Walks and Wins ')
sns.lineplot(df['Base on Balls'],df['Wins'], color='darkorange') 
plt.xlabel("Walks")
plt.ylabel("Wins")
# Out:
# Text(0, 0.5, 'Wins')

# %%
plt.figure(figsize=[10,6])
plt.title('Comparision between Doubles and Wins')
sns.lineplot(df['Doubles'],df['Wins'],color="green");
plt.xlabel("Doubles")
plt.ylabel("Wins")
# Out:
# Text(0, 0.5, 'Wins')

# %%
plt.figure(figsize=[10,6])
plt.title('Comparision between Stolen Bases and Wins')
sns.lineplot(df['Stolen Base'],df['Wins'],color="red");
plt.xlabel("Stolen Bases")
plt.ylabel("Wins")
# Out:
# Text(0, 0.5, 'Wins')

# %%
plt.figure(figsize=[10,6])
plt.title('Comparision between Runs Allowed and Wins')
sns.scatterplot(df['Runs Average'],df['Wins']);
plt.xlabel("Runs Allowed")
plt.ylabel("Wins")
# Out:
# Text(0, 0.5, 'Wins')

# %% [markdown]
# The target column has negative linear relationship with the feature Runs Allowed, since the data is falling from left to right which means label is highly correlated with the feature.

# %%
plt.figure(figsize=[10,6])
plt.title('Comparision between Earned Runs and Wins')
sns.scatterplot(df['Earned Runs'],df['Wins']);
plt.xlabel("Earned Runs")
plt.ylabel("Wins")
# Out:
# Text(0, 0.5, 'Wins')

# %%
plt.figure(figsize=[10,6])
plt.title('Comparision between Earned Runs Average and Wins')
sns.scatterplot(df['Earned Run Average'],df['Wins']);
plt.xlabel("Earned Runs Average")
plt.ylabel("Wins")
# Out:
# Text(0, 0.5, 'Wins')

# %%
plt.figure(figsize=(10,10))
sns.barplot(x="Runs Scored", y="Wins", data=df)
plt.show()

# %% [markdown]
# Feature "Runs Scored" and it's unique values are distributed unevenly when it comes to relating with our label "Wins"

# %%
plt.figure(figsize=(15,15))
sns.barplot(x="At Bat", y="Wins", data=df)
plt.show()

# %%
plt.figure(figsize=(15,15))
sns.barplot(x="Doubles", y="Wins", data=df)
plt.show()

# %% [markdown]
# Feature "Doubles" and it's unique values again do not form any definite pattern when it comes to relating with our label "Wins"

# %%
plt.figure(figsize=(15,15))
sns.barplot(x="Triples", y="Wins", data=df)
plt.show()

# %% [markdown]
# Feature "Triples" and it's unique values are distributed unevenly when it comes to relating with our label "Wins"

# %%
plt.figure(figsize=(15,15))
sns.barplot(x="Home Runs", y="Wins", data=df)
plt.show()

# %%
plt.figure(figsize=(15,15))
sns.barplot(x="Base on Balls", y="Wins", data=df)
plt.show()

# %%
plt.figure(figsize=(15,15))
sns.barplot(x="Strike Outs", y="Wins", data=df)
plt.show()

# %%
plt.figure(figsize=(15,15))
sns.barplot(x="Stolen Base", y="Wins", data=df)
plt.show()

# %%
plt.figure(figsize=(15,15))
sns.barplot(x="Earned Runs", y="Wins", data=df)
plt.show()

# %%
plt.figure(figsize=(15,15))
sns.barplot(x="Complete Game", y="Wins", data=df)
plt.show()

# %% [markdown]
# Feature "Complete Game" and it's unique values do not show any pattern when it comes to relating with our label "Wins"

# %%
plt.figure(figsize=(15,15))
sns.barplot(x="Shut Outs", y="Wins", data=df)
plt.show()

# %% [markdown]
# Feature "Shut Outs" and it's unique values are also distributed unevenly when it comes to relating with our label "Wins"

# %%
plt.figure(figsize=(15,15))
sns.barplot(x="Saves", y="Wins", data=df)
plt.show()

# %% [markdown]
# Feature "Saves" and it's unique values show a slightly increasig pattern when it comes to relating with our label "Wins"

# %%
for i in df:
    sns.lmplot(x = i , y ='Wins' , data = df)

# %%
#Checking the pairwise relation in the dataset.
sns.pairplot(df,hue="Wins",palette="husl")

# %% [markdown]
# This pair plot gives the pairwise relation between the columns which is plotted on the basis of target variable "W". Here we can observe the relation between the features and label.
#
# From this pairplot we can observe that the existence of correlation between two variables and on the diagonal we can see distribution plotting.
#
# We can infer the linear relationship between the features RA and ERA, RA and ER and ER and ERA.
# Also the correlation exists between the features and there outliers present in some columns

# %% [markdown]
# # Removing outliers

# %%
df.columns
# Out:
# Index(['Wins', 'Runs Scored', 'At Bat', 'Hits', 'Doubles', 'Triples',
#        'Home Runs', 'Base on Balls', 'Strike Outs', 'Stolen Base',
#        'Runs Average', 'Earned Runs', 'Earned Run Average', 'Complete Game',
#        'Shut Outs', 'Saves', 'Errors'],
#       dtype='object')

# %%
# Features containing outliers
features = df[["Runs Scored","Earned Run Average","Shut Outs","Saves","Errors"]]

# %%
from scipy.stats import zscore

z=np.abs(zscore(features))

z
# Out:
#     Runs Scored  Earned Run Average  Shut Outs     Saves    Errors
# 0      0.619078            0.506955   0.814629  1.671607  0.461470
# 1      0.134432            0.254598   0.172800  0.249879  0.607197
# 2      0.332906            0.641347   0.320914  0.654856  1.117242
# 3      1.146419            0.053010   0.567771  0.784104  0.485758
# 4      0.013270            1.531318   0.172800  1.042600  0.607197
# 5      3.509647            0.350165   0.320914  1.171848  0.461470
# 6      1.311430            0.165003   1.802057  0.637623  0.097152
# 7      0.428681            0.209800   0.320914  0.008617  1.262970
# 8      0.765626            0.484557   0.172800  2.188598  0.048576
# 9      1.034489            0.792164   0.320914  0.396360  0.194303
# 10     1.086415            0.635374   0.567771  0.249879  1.797303
# 11     0.705622            0.865333   0.419657  0.525608  0.680061
# 12     0.471376            0.036584   0.172800  0.379127  0.097152
# ...

# %%
new_df = df[(z<3).all(axis=1)]
new_df
# Out:
#     Wins  Runs Scored  At Bat  Hits  Doubles  Triples  Home Runs  \
# 0     95          724    5575  1497      300       42        139
# 1     83          696    5467  1349      277       44        156
# 2     81          669    5439  1395      303       29        141
# 3     76          622    5533  1381      260       27        136
# 4     74          689    5605  1515      289       49        151
# 6     87          764    5567  1397      272       19        212
# 7     81          713    5485  1370      246       20        217
# 8     80          644    5485  1383      278       32        167
# 9     78          748    5640  1495      294       33        161
# 10    88          751    5511  1419      279       32        172
# 11    86          729    5459  1363      278       26        230
# 12    85          661    5417  1331      243       21        176
# 13    76          656    5544  1379      262       22        198
# ...

# %%
df.shape
# Out:
# (30, 17)

# %%
new_df.shape
# Out:
# (29, 17)

# %% [markdown]
# The new dataset contains 29 rows and 17 columns.

# %%
# Checking the the data loss
data_loss = (30-29)/30*100
data_loss
# Out:
# 3.3333333333333335

# %% [markdown]
# Let's remove the outliers and check data loss using IQR method.

# %%
# 1st quantile
Q1=features.quantile(0.25)

# 3rd quantile
Q3=features.quantile(0.75)

# IQR
IQR=Q3 - Q1

df1=df[~((df < (Q1 - 1.5 * IQR)) |(df > (Q3 + 1.5 * IQR))).any(axis=1)]

# %%
df1.shape
# Out:
# (20, 17)

# %% [markdown]
# The new dataframe using IQR method has 20 rows and 17 columns.

# %%
df.shape
# Out:
# (30, 17)

# %%
#checking the dataloss
data_loss = (30-20)/30*100
data_loss
# Out:
# 33.33333333333333

# %% [markdown]
# In IQR method we are losing more data as compared to Zscore method.

# %%
# Checking the skewness
new_df.skew()
# Out:
# Wins                  0.119013
# Runs Scored          -0.215364
# At Bat                0.169573
# Hits                  0.783772
# Doubles              -0.335304
# Triples               0.090124
# Home Runs             0.450862
# Base on Balls         0.151193
# Strike Outs          -0.233815
# Stolen Base           0.494966
# Runs Average          0.018155
# Earned Runs           0.018461
# Earned Run Average    0.016693
# Complete Game         0.854980
# Shut Outs             0.526943
# Saves                 0.627480
# Errors                0.840271
# dtype: float64

# %% [markdown]
# The skewness present in the columns "Hits", "Complete Game", "Shuts Outs", "Saves" and "Errors". Will remove this now.

# %%
skewed_features = ["Shut Outs", "Complete Game", "Errors","Saves"]

# %%
# Using yeo-johnson method to remove the skewness
from sklearn.preprocessing import PowerTransformer
scaler = PowerTransformer(method='yeo-johnson')
'''
parameters:
method = 'box-cox' or 'yeo-johnson'
'''
# Out:
# "\nparameters:\nmethod = 'box-cox' or 'yeo-johnson'\n"

# %%
new_df[skewed_features] = scaler.fit_transform(new_df[skewed_features].values)
new_df[skewed_features].head()
# Out:
#    Shut Outs  Complete Game    Errors     Saves
# 0  -0.787002      -0.307098 -0.348265  1.532753
# 1   0.236737      -0.307098 -0.540820  0.312020
# 2  -0.252844       2.011315 -1.326125 -0.664137
# 3  -0.513555       1.264463  0.650818 -0.820689
# 4   0.236737       1.264463 -0.540820 -1.149165

# %%
new_df['Hits'] = np.log(new_df['Hits'])

# %%
new_df.skew()
# Out:
# Wins                  0.119013
# Runs Scored          -0.215364
# At Bat                0.169573
# Hits                  0.738423
# Doubles              -0.335304
# Triples               0.090124
# Home Runs             0.450862
# Base on Balls         0.151193
# Strike Outs          -0.233815
# Stolen Base           0.494966
# Runs Average          0.018155
# Earned Runs           0.018461
# Earned Run Average    0.016693
# Complete Game        -0.045947
# Shut Outs             0.000529
# Saves                -0.000925
# Errors                0.065585
# dtype: float64

# %%
features_skewed = ["Hits","Complete Game", "Shut Outs", "Saves", "Errors"]
plt.figure(figsize=(20,25), facecolor='white')
plotnumber = 1

for column in new_df[features_skewed]:
    if plotnumber<=18:
        ax = plt.subplot(6,3,plotnumber)
        sns.distplot(new_df[column],color='r')
        plt.xlabel(column,fontsize=20)
    plotnumber+=1
plt.show()

# %% [markdown]
# We can see the data is normally distributed and skewness is also removed but in hits column there is still skewness present

# %%
# Checking the correlation between features and the target
cor = new_df.corr()
cor
# Out:
#                         Wins  Runs Scored    At Bat      Hits   Doubles  \
# Wins                1.000000     0.390451 -0.085780 -0.020787  0.384886
# Runs Scored         0.390451     1.000000  0.438022  0.432235  0.469293
# At Bat             -0.085780     0.438022  1.000000  0.770155  0.490752
# Hits               -0.020787     0.432235  0.770155  1.000000  0.527354
# Doubles             0.384886     0.469293  0.490752  0.527354  1.000000
# Triples            -0.206737     0.134204  0.445604  0.579733  0.342419
# Home Runs           0.245697     0.586894 -0.064653 -0.219201 -0.098695
# Base on Balls       0.447513     0.258450 -0.137850 -0.221773  0.211243
# Strike Outs         0.156469     0.081158 -0.111243 -0.373302 -0.096772
# Stolen Base        -0.169503     0.075323  0.373674  0.420201  0.194308
# Runs Average       -0.823176    -0.013858  0.315499  0.243639 -0.215196
# Earned Runs        -0.815308     0.007727  0.309146  0.279955 -0.224993
# ...

# %% [markdown]
# The above method shows the correlation between the dependent and independent variables

# %%
plt.figure(figsize=(16,9))
sns.heatmap(new_df.corr(),linewidths=.1,fmt='0.2f', cmap="Blues_r", annot = True)
plt.yticks(rotation=0);

# %% [markdown]
# This method shows the both positive and negative correlation.
#
# The target wins column is positively correlated with the other input features save, shut outs,base on balls,home runs,doubles, runs scored and strike outs.
#
# The target wins is highly negatively correlated with the features earned run average,earned runs and runs average.
#
# The target wins is also negatively correlated with the features errors,stolen base,triples and at bat.
#
# Further the column hits and complete game has no correlation with the output column

# %%
cor['Wins'].sort_values(ascending=False)
# Out:
# Wins                  1.000000
# Saves                 0.756713
# Shut Outs             0.481626
# Base on Balls         0.447513
# Runs Scored           0.390451
# Doubles               0.384886
# Home Runs             0.245697
# Strike Outs           0.156469
# Complete Game         0.007696
# Hits                 -0.020787
# Errors               -0.079633
# At Bat               -0.085780
# Stolen Base          -0.169503
# Triples              -0.206737
# Earned Runs          -0.815308
# Runs Average         -0.823176
# Earned Run Average   -0.826952
# Name: Wins, dtype: float64

# %% [markdown]
# From the above method we find that wins,saves,shut outs, base on balls, run scored,doubles,home runs,strike out and complete game have positively correlation
# Furthr columns hits,errors,at bat,stolen base,triples,earned runs, runs average and earned run average have negatively correlated values

# %%
plt.figure(figsize=(20,6))
new_df.corr()['Wins'].sort_values(ascending=False).drop(['Wins']).plot(kind='bar',color='r')
plt.xlabel('Feature',fontsize=16)
plt.ylabel('output',fontsize=16)
plt.title('correlation between output and input fetures using bar plot',fontsize=16)
plt.show()

# %% [markdown]
# From this method we can identify the dataset input column hits and complete game  has vey less correlation with target or label column

# %%
new_df.drop("Hits", axis=1, inplace=True)

# %%
new_df.drop("Complete Game", axis=1, inplace=True)

# %%
new_df.head()
# Out:
#    Wins  Runs Scored  At Bat  Doubles  Triples  Home Runs  Base on Balls  \
# 0    95          724    5575      300       42        139            383
# 1    83          696    5467      277       44        156            439
# 2    81          669    5439      303       29        141            533
# 3    76          622    5533      260       27        136            404
# 4    74          689    5605      289       49        151            455
#
#    Strike Outs  Stolen Base  Runs Average  Earned Runs  Earned Run Average  \
# 0          973          104           641          601                3.73
# 1         1264           70           700          653                4.07
# 2         1157           86           640          584                3.67
# 3         1231           68           701          643                3.98
# 4         1259           83           803          746                4.64
#
#    Shut Outs     Saves    Errors
# 0  -0.787002  1.532753 -0.348265
# ...

# %% [markdown]
# The new dataset after removing the less correlation column

# %%
x = new_df.drop("Wins", axis=1)
y = new_df["Wins"]

# %% [markdown]
# This method separates the target variable and independent variable.

# %%
x.shape
# Out:
# (29, 14)

# %%
y.shape
# Out:
# (29,)

# %%
x.head()
# Out:
#    Runs Scored  At Bat  Doubles  Triples  Home Runs  Base on Balls  \
# 0          724    5575      300       42        139            383
# 1          696    5467      277       44        156            439
# 2          669    5439      303       29        141            533
# 3          622    5533      260       27        136            404
# 4          689    5605      289       49        151            455
#
#    Strike Outs  Stolen Base  Runs Average  Earned Runs  Earned Run Average  \
# 0          973          104           641          601                3.73
# 1         1264           70           700          653                4.07
# 2         1157           86           640          584                3.67
# 3         1231           68           701          643                3.98
# 4         1259           83           803          746                4.64
#
#    Shut Outs     Saves    Errors
# 0  -0.787002  1.532753 -0.348265
# 1   0.236737  0.312020 -0.540820
# ...

# %% [markdown]
# The above dataset containg all independent variables.

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
x = pd.DataFrame(scaler.fit_transform(x), columns=x.columns)
x
# Out:
#     Runs Scored    At Bat   Doubles   Triples  Home Runs  Base on Balls  \
# 0      0.959398  0.830084  1.556538  1.010845  -0.765863      -1.536359
# 1      0.331147 -0.702831  0.201171  1.208917  -0.181389      -0.495021
# 2     -0.274666 -1.100253  1.733325 -0.276617  -0.697101       1.252941
# 3     -1.329231  0.233951 -0.800621 -0.474688  -0.869006      -1.145857
# 4      0.174084  1.255894  0.908319  1.704094  -0.353293      -0.197495
# 5      1.856900  0.716535 -0.093474 -1.266972   1.743939       1.643442
# 6      0.712585 -0.447345 -1.625627 -1.167936   1.915843      -0.885522
# 7     -0.835605 -0.447345  0.260100  0.020490   0.196801      -0.550807
# 8      1.497899  1.752672  1.202964  0.119526  -0.009484       0.230197
# 9      1.565212 -0.078310  0.319029  0.020490   0.368705       0.695081
# 10     1.071586 -0.816380  0.260100 -0.573723   2.362794       0.378960
# 11    -0.454167 -1.412514 -1.802414 -1.068901   0.506228      -0.569402
# ...

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
vif = pd.DataFrame()
vif["VIF factor"] = [variance_inflation_factor(x.values,i)
              for i in range(len(x.columns))]
vif["Features"] = x.columns
print(vif)
# Out:
#      VIF factor            Features
# 0      6.219825         Runs Scored
# 1      9.828077              At Bat
# 2      2.683572             Doubles
# 3      3.196853             Triples
# 4      7.369072           Home Runs
# 5      2.686472       Base on Balls
# 6      2.741072         Strike Outs
# 7      1.757901         Stolen Base
# 8    179.096825        Runs Average
# 9   1754.643859         Earned Runs
# 10  1310.260128  Earned Run Average
# 11     3.086344           Shut Outs
# 12     4.021573               Saves
# 13     1.742105              Errors

# %% [markdown]
# From the above output we find that in some columns there is high vif value above 10 in input column at bat ,runs average,earned runs and earned run average
#
# Further input column earned  runs has the highest vif value

# %%
x.drop("Earned Runs", axis=1, inplace=True)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif = pd.DataFrame()
vif["VIF factor"] = [variance_inflation_factor(x.values,i)
              for i in range(len(x.columns))]
vif["Features"] = x.columns
print(vif)
# Out:
#     VIF factor            Features
# 0     4.352902         Runs Scored
# 1     3.177214              At Bat
# 2     2.597985             Doubles
# 3     3.072775             Triples
# 4     4.949255           Home Runs
# 5     2.561982       Base on Balls
# 6     2.661842         Strike Outs
# 7     1.680467         Stolen Base
# 8   119.939744        Runs Average
# 9   111.859162  Earned Run Average
# 10    2.932319           Shut Outs
# 11    2.112465               Saves
# 12    1.742101              Errors

# %% [markdown]
# After removing the highest vif column we have still 2 input column run average and earned run average with high vif values

# %%
x.drop("Runs Average", axis=1, inplace=True)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif = pd.DataFrame()
vif["VIF factor"] = [variance_inflation_factor(x.values,i)
              for i in range(len(x.columns))]
vif["Features"] = x.columns
print(vif)
# Out:
#     VIF factor            Features
# 0     4.250076         Runs Scored
# 1     2.238746              At Bat
# 2     2.597917             Doubles
# 3     3.030073             Triples
# 4     4.562014           Home Runs
# 5     2.222720       Base on Balls
# 6     2.042786         Strike Outs
# 7     1.568151         Stolen Base
# 8     3.878177  Earned Run Average
# 9     2.651314           Shut Outs
# 10    1.954370               Saves
# 11    1.493128              Errors

# %% [markdown]
# After removing the high multi colinearity values, now our dataset did not have any high vif values

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score

# %%
maxAccu=0
maxRS=0
for i in range(1,200):
    x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=.33, random_state=i)
    ln=LinearRegression()
    ln.fit(x_train, y_train)
    pred =ln.predict(x_test)
    acc=r2_score(y_test, pred)
    if acc>maxAccu:
        maxAccu=acc
        maxRS=i
print("Maximum r2 score is ",maxAccu," on Random_state ",maxRS)
# Out:
# Maximum r2 score is  0.8922187185754255  on Random_state  30

# %% [markdown]
# From the above model we are getting maximum r2 score as 89 on random state 30

# %%
from sklearn.linear_model import LinearRegression, Lasso,Ridge
from sklearn.ensemble import RandomForestRegressor, AdaBoostRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor as KNN
from sklearn.svm import SVR
from sklearn.linear_model import SGDRegressor
from sklearn.metrics import classification_report
from sklearn.model_selection import cross_val_score
from sklearn import metrics

# %%
LN = LinearRegression()
LN.fit(x_train,y_train)

pred=LN.predict(x_test)
print('Score:',r2_score(y_test,pred))

print('Mean absolute error:',mean_absolute_error(y_test, pred))

print("Mean squared error:",mean_squared_error(y_test,pred))

print ("Root mean squared error:",np.sqrt(mean_squared_error(y_test,pred)))
# Out:
# Score: 0.8857266570224158
# Mean absolute error: 3.2109237910511355
# Mean squared error: 12.816898148365846
# Root mean squared error: 3.5800695731180765

# %% [markdown]
# The above method show the score value for Linear Regression model is 88%.

# %%
from sklearn.linear_model import Ridge
rd=Ridge(alpha=.01)
rd.fit(x_train,y_train)
rd.score(x_train,y_train)
predridge=rd.predict(x_test)
print('R2_Score:',r2_score(y_test,predridge))
print('Mean absolute error:',metrics.mean_absolute_error(y_test, predridge))
print('Mean squared error:',mean_squared_error(y_test,predridge))
print("Root mean squared error:",np.sqrt(metrics.mean_squared_error(y_test,predridge)))
# Out:
# R2_Score: 0.8863931105076079
# Mean absolute error: 3.199198852391926
# Mean squared error: 12.74214872546669
# Root mean squared error: 3.56961464663438

# %% [markdown]
# The above method show the score for Ridge Regressor is 88

# %%
from sklearn.linear_model import Lasso
ls=Lasso(alpha=.0001)
ls.fit(x_train,y_train)
ls.score(x_train,y_train)
predlasso=ls.predict(x_test)
print('R2_Score:',r2_score(y_test,predlasso))
print('Mean absolute error:',metrics.mean_absolute_error(y_test, predlasso))
print('Mean squared error:',metrics.mean_squared_error(y_test, predlasso))
print("Root mean squared error:",np.sqrt(metrics.mean_squared_error(y_test, predlasso)))
# Out:
# R2_Score: 0.8857831502075717
# Mean absolute error: 3.2098899395593348
# Mean squared error: 12.810561872718761
# Root mean squared error: 3.5791845262180546

# %% [markdown]
# The above method show the score for Lasso Regressor is 88

# %%
from sklearn.model_selection import cross_val_score

# %%
score=cross_val_score(LN,x,y,cv=5)
print(score)
print(score.mean())
print(score.std())
# Out:
# [ 0.4461438  -0.8598873   0.59765595  0.89388912  0.78941905]
# 0.3734441230489941
# 0.6356981566547972

# %% [markdown]
# From the above step we find the cross validation score for the linear regression for the mean is 0.3734441230489941

# %%
score=cross_val_score(rd,x,y,cv=5)
print(score)
print(score.mean())
print(score.std())
# Out:
# [ 0.44757351 -0.8603949   0.59962445  0.89428059  0.79012209]
# 0.37424114599346653
# 0.63622314013452

# %% [markdown]
# Cross validation score for the ridge regressor  is 0.37424114599346653

# %%
score=cross_val_score(ls,x,y,cv=5)
print(score)
print(score.mean())
print(score.std())
# Out:
# [ 0.44628109 -0.85969048  0.59781667  0.89394688  0.78947831]
# 0.37356649346325155
# 0.6356534745468676

# %% [markdown]
# Cross validation score for the lasso regressor is 0.37356649346325155

# %%
from sklearn.model_selection import GridSearchCV

# %%
parameters = {'alpha':[0.01, 0.1, 1.0,10.26],
              'selection':['cyclic','random'],
              'max_iter':[2,4,6,8,10],
              'tol':[100,1000],
              'fit_intercept':['bool']}

# %%
GCV=GridSearchCV(Lasso(),parameters,cv=5)

# %%
GCV.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=Lasso(),
#              param_grid={'alpha': [0.01, 0.1, 1.0, 10.26],
#                          'fit_intercept': ['bool'],
#                          'max_iter': [2, 4, 6, 8, 10],
#                          'selection': ['cyclic', 'random'],
#                          'tol': [100, 1000]})

# %%
GCV.best_params_
# Out:
# {'alpha': 1.0,
#  'fit_intercept': 'bool',
#  'max_iter': 2,
#  'selection': 'random',
#  'tol': 100}

# %%
BaseBall = Lasso(alpha=1.0, fit_intercept="bool", max_iter=2, selection="random", tol=100)
BaseBall.fit(x_train, y_train)
pred = BaseBall.predict(x_test)
print('R2_Score:',r2_score(y_test,predlasso)*100)
print("Root mean squared error:",np.sqrt(metrics.mean_squared_error(y_test, predlasso)))
# Out:
# R2_Score: 88.57831502075717
# Root mean squared error: 3.5791845262180546

# %%
import joblib
joblib.dump(BaseBall,"Baseball.file.obj")
# Out:
# ['Baseball.file.obj']

# %%
model=joblib.load("Baseball.file.obj")

# %%
prediction = model.predict(x_test)
prediction
# Out:
# array([92.0781343 , 78.12618263, 77.70528412, 82.94690749, 96.41064934,
#        74.8269009 , 76.56168998, 77.5930504 , 62.03814333, 73.31187473])

# %%
pd.DataFrame([model.predict(x_test)[:],y_test[:]],index=["Predicted","Original"])
# Out:
#                    0          1          2          3           4          5  \
# Predicted  92.078134  78.126183  77.705284  82.946907   96.410649  74.826901
# Original   98.000000  76.000000  79.000000  84.000000  100.000000  88.000000
#
#                   6         7          8          9
# Predicted  76.56169  77.59305  62.038143  73.311875
# Original   74.00000  83.00000  68.000000  68.000000

# %%
plt.figure(figsize=(10,10))
plt.scatter(y_test, prediction, c='r')
plt1 = max(max(prediction), max(y_test))
plt2 = min(min(prediction), min(y_test))
plt.plot([plt1, plt2], [plt1, plt2], 'b-')
plt.xlabel('Actual Win', fontsize=15)
plt.ylabel('Predicted Win', fontsize=15)
plt.title("Lasso Regressor")
plt.show()

# %% [markdown]
# The above plot shows the blue line represents the actual win and red dots are the predicted win.
